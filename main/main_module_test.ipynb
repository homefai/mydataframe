# %%
from dao.config import BASE_PATH, DATA_PATH, DATA_WEATHERDATA_PATH
import os
from myDFrame import myDFrame
import matplotlib.pyplot as plt

# %%
from os import listdir

# %%
data_list=listdir(DATA_WEATHERDATA_PATH)

# %%
data_file=os.path.join(DATA_WEATHERDATA_PATH, data_list[0])

# %%
data_file
# Out:
# '/home/allen/myDoc/myDFrame/code/mydataframe/data/historical-hourly-weather-data/pressure.csv'

# %%
pressure=myDFrame.read_csv(data_file)

# %%
pressure.to_datetime(col_name='datetime', format='%Y-%m-%d %H:%M:%S')

# %%
pressure.get_df()
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 0     2012-10-01 12:00:00        NaN       NaN            NaN      NaN
# 1     2012-10-01 13:00:00        NaN    1024.0         1009.0   1027.0
# 2     2012-10-01 14:00:00        NaN    1024.0         1009.0   1027.0
# 3     2012-10-01 15:00:00        NaN    1024.0         1009.0   1028.0
# 4     2012-10-01 16:00:00        NaN    1024.0         1009.0   1028.0
# 5     2012-10-01 17:00:00        NaN    1024.0         1009.0   1029.0
# 6     2012-10-01 18:00:00        NaN    1024.0         1010.0   1030.0
# 7     2012-10-01 19:00:00        NaN    1024.0         1010.0   1031.0
# 8     2012-10-01 20:00:00        NaN    1024.0         1010.0   1031.0
# 9     2012-10-01 21:00:00        NaN    1024.0         1010.0   1032.0
# 10    2012-10-01 22:00:00        NaN    1024.0         1011.0   1033.0
# 11    2012-10-01 23:00:00        NaN    1024.0         1011.0   1034.0
# ...

# %%
pressure.glt('Portland' , 1001).get_df()
# Out:
#                  datetime  Vancouver  Portland  San Francisco  Seattle  \
# 1     2012-10-01 13:00:00        NaN    1024.0         1009.0   1027.0
# 2     2012-10-01 14:00:00        NaN    1024.0         1009.0   1027.0
# 3     2012-10-01 15:00:00        NaN    1024.0         1009.0   1028.0
# 4     2012-10-01 16:00:00        NaN    1024.0         1009.0   1028.0
# 5     2012-10-01 17:00:00        NaN    1024.0         1009.0   1029.0
# 6     2012-10-01 18:00:00        NaN    1024.0         1010.0   1030.0
# 7     2012-10-01 19:00:00        NaN    1024.0         1010.0   1031.0
# 8     2012-10-01 20:00:00        NaN    1024.0         1010.0   1031.0
# 9     2012-10-01 21:00:00        NaN    1024.0         1010.0   1032.0
# 10    2012-10-01 22:00:00        NaN    1024.0         1011.0   1033.0
# 11    2012-10-01 23:00:00        NaN    1024.0         1011.0   1034.0
# 12    2012-10-02 00:00:00        NaN    1024.0         1011.0   1035.0
# ...

# %%
pressure.row_at(100).get_df()
# Out:
# datetime             2012-10-05 16:00:00
# Vancouver                            NaN
# Portland                            1022
# San Francisco                       1019
# Seattle                             1026
# Los Angeles                         1019
# San Diego                           1020
# Las Vegas                           1016
# Phoenix                             1018
# Albuquerque                         1025
# Denver                              1024
# San Antonio                         1020
# Dallas                              1020
# Houston                             1021
# Kansas City                         1023
# Minneapolis                         1015
# Saint Louis                         1020
# Chicago                             1017
# Nashville                           1026
# Indianapolis                        1022
# Atlanta                             1026
# Detroit                             1019
# Jacksonville                        1023
# ...

# %%
pressure.df.loc[:, ['datetime', 'Portland']].plot()

# %%
portland_pressure=pressure.df.loc[:, ['datetime', 'Portland']]

# %%
portland_pressure['MA5'] =pressure.df['Portland'].rolling(window=50).mean()

# %%
portland_pressure.plot(x='datetime', y='MA5')

# %%
plt.show()
